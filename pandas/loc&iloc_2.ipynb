# %%
import pandas as pd

# %%
# 붓꽃 데이터 읽어 들이기

# %%
iris_data = pd.read_csv("C:\\Users\\user\\AI_vision\\data\\iris.csv", encoding="utf-8")

# %%
iris_data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# 6            4.6         3.4          1.4         0.3     Iris-setosa
# 7            5.0         3.4          1.5         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 9            4.9         3.1          1.5         0.1     Iris-setosa
# 10           5.4         3.7          1.5         0.2     Iris-setosa
# 11           4.8         3.4          1.6         0.2     Iris-setosa
# ...

# %%
iris_data.loc[2] #index를 기준으로 행 데이터를 불러온다
# Out:
# SepalLength            4.7
# SepalWidth             3.2
# PetalLength            1.3
# PetalWidth             0.2
# Name           Iris-setosa
# Name: 2, dtype: object

# %%
iris_data.loc[[2]] #index를 기준으로 행 데이터를 dataframe형태로 불러온다
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 2          4.7         3.2          1.3         0.2  Iris-setosa

# %%
iris_data.iloc[[2]] #행번호를 기준으로 행 데이터를 불러온다
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 2          4.7         3.2          1.3         0.2  Iris-setosa

# %%
iris_data.loc[:, ["SepalLength", "SepalWidth", "PetalLength","PetalWidth"]]
# 모든 행에 대해 "문자열"에 해당되는 데이터만 가져온다
#"Name" 열이 잘라져 나온 것을 볼 수 있다
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# 5            5.4         3.9          1.7         0.4
# 6            4.6         3.4          1.4         0.3
# 7            5.0         3.4          1.5         0.2
# 8            4.4         2.9          1.4         0.2
# 9            4.9         3.1          1.5         0.1
# 10           5.4         3.7          1.5         0.2
# 11           4.8         3.4          1.6         0.2
# 12           4.8         3.0          1.4         0.1
# 13           4.3         3.0          1.1         0.1
# 14           5.8         4.0          1.2         0.2
# 15           5.7         4.4          1.5         0.4
# ...

# %%
iris_data.loc[:, "Name"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# 129    Iris-virginica
# ...

# %%
iris_data.iloc[:,:3] 
#iloc는 행번호를 기준으로 데이터를 불러온다
# 그러므로 SepalLength(0), SepalWidth(1), PetalLength(2)의 열데터만 출력한다.
# Out:
#      SepalLength  SepalWidth  PetalLength
# 0            5.1         3.5          1.4
# 1            4.9         3.0          1.4
# 2            4.7         3.2          1.3
# 3            4.6         3.1          1.5
# 4            5.0         3.6          1.4
# 5            5.4         3.9          1.7
# 6            4.6         3.4          1.4
# 7            5.0         3.4          1.5
# 8            4.4         2.9          1.4
# 9            4.9         3.1          1.5
# 10           5.4         3.7          1.5
# 11           4.8         3.4          1.6
# 12           4.8         3.0          1.4
# 13           4.3         3.0          1.1
# 14           5.8         4.0          1.2
# 15           5.7         4.4          1.5
# 16           5.4         3.9          1.3
# 17           5.1         3.5          1.4
# 18           5.7         3.8          1.7
# 19           5.1         3.8          1.5
# 20           5.4         3.4          1.7
# ...

# %%
iris_data.loc[[1,4], ['SepalLength']]
# Out:
#    SepalLength
# 1          4.9
# 4          5.0

# %%
iris_data.iloc[[1,4], [0]]
# Out:
#    SepalLength
# 1          4.9
# 4          5.0
